# %%
# !pip3 install mne
# !pip install POT
# !git clone https://github.com/vpeterson/otda-mibci.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mne
#   Downloading mne-1.4.0-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 39.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.10/dist-packages (from mne) (1.22.4)
# Requirement already satisfied: scipy>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from mne) (1.10.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mne) (3.7.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from mne) (4.65.0)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.10/dist-packages (from mne) (1.6.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from mne) (4.4.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from mne) (23.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from mne) (3.1.2)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne) (2.27.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->mne) (2.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mne) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mne) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mne) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mne) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mne) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mne) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mne) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mne) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.4)
# Installing collected packages: mne
# Successfully installed mne-1.4.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting POT
#   Downloading POT-0.9.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (702 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 702.9/702.9 kB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.10/dist-packages (from POT) (1.22.4)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from POT) (1.10.1)
# Installing collected packages: POT
# Successfully installed POT-0.9.0
# Cloning into 'otda-mibci'...
# remote: Enumerating objects: 270, done.
# remote: Counting objects: 100% (150/150), done.
# remote: Compressing objects: 100% (114/114), done.
# remote: Total 270 (delta 82), reused 87 (delta 36), pack-reused 120
# Receiving objects: 100% (270/270), 82.39 MiB | 17.11 MiB/s, done.
# Resolving deltas: 100% (142/142), done.

# %%
import numpy as np
import sys
sys.path.insert(1, 'otda-mibci')
import mne
import os.path as op
import os
from mne.decoding import CSP
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, 'C:/Users/Visitante/Documents/otda-mibci-master/otda-mibci-master')
from MIOTDAfunctions import*
from sklearn.metrics import balanced_accuracy_score, accuracy_score
import ot.plot
from tabulate import tabulate

# %%
def Backward_GroupLasso_Transport(Gtr_daot, Ytr_daot, regu_, Gtr, Ytr, Gval, Yval, Gte, lda, metric):
      
    botda = ot.da.SinkhornL1l2Transport(metric=metric, reg_e=regu_[0], reg_cl=regu_[1])
    # learn params of transport
    botda.fit(Xs=Gval, ys=Yval, Xt=Gtr_daot)
    botda_matrix = botda.coupling_
    #transport testing samples
    transp_Xt_backward=botda.transform(Xs=Gte)
    
    # Compute accuracy without retraining    
    yt_predict = lda.predict(transp_Xt_backward) 
    
    return yt_predict, transp_Xt_backward, botda_matrix

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os.path as op
data_path = op.join('/content/drive/MyDrive/Proyecto_coadaptiveBCI/Simulaciones/simulated data/MI vs rest')

# %%
sessions = list(range(2,10))
erd = np.array([0.5, 0.45, 0.4, 0.35, 0.3, 0.25, 0.2, 0.15, 0.1])
for s in list(range(9,10)): # start in 2 to avoid training in 0.5 ERD
    Train_session = s
    sessions = list(range(1,10))
    Test_sessions = sessions.copy()
    Test_sessions.remove(s)
             
    #result_path =  op.join(general_result_path, 'Train_' + str(Train_session))
    
    # %% Load Training data
    Data_S1 = op.join(data_path, 'session' + str(Train_session) +'_epochs_epo.fif')
    epochs_S1 = mne.read_epochs(Data_S1, preload=True, verbose=False)
    # # resample to 250 Hz
    epochs_S1 = epochs_S1.resample(250)
    epochs_S1_array = epochs_S1.get_data()  # Epoched data as a numpy array
    # # filter data between 8 an 30 hz
    epochs_S1_array=mne.filter.filter_data(epochs_S1_array, 250, 8, 30)
    ch_names = epochs_S1.ch_names  # Channels names

    # %% Training - Learn CSP+LDA from source data
    Xtr = epochs_S1_array.copy()
    Ytr = epochs_S1.events[:,2].copy()
    csp = CSP(n_components=2, reg='empirical', log=True, norm_trace=False, cov_est='epoch') #creating obj
    #learn csp filters
    Gtr = csp.fit_transform(Xtr, Ytr)
    #learn lda
    lda = LinearDiscriminantAnalysis()
    lda.fit(Gtr,Ytr)
    lda.score(Gtr,Ytr)
       
    fig = csp.plot_patterns(epochs_S1.info, ch_type='eeg', units='Patterns (AU)', size=1.5)
 #   fig.savefig(op.join(result_path, 'CSP_pattern'+'.svg'), format='svg',
 #           transparent=True, dpi=2000, bbox_inches='tight', pad_inches=0)
    plt.show()
    
    #Plot first 2 features
    features = Gtr[:,0:2]
    fig, axs = plt.subplots()
    axs.scatter(features[Ytr==1, 0], features[Ytr==1, 1], c='orange', label='MI')
    axs.scatter(features[Ytr==2, 0], features[Ytr==2, 1], c='darkturquoise', label='REST')
    axs.set_title("Training Session " + str(s) + " - ERD = " + str(erd[s-1]) + "\nLDA score: " + str(lda.score(Gtr,Ytr)))
    axs.legend()
    b, w1, w2 = lda.intercept_[0], lda.coef_[0][0], lda.coef_[0][1]
    xx = np.array(axs.get_xlim())
    xlim = xx
    ylim = np.array(axs.get_ylim())
    axs.plot(xx, -(b+xx*w1)/w2, c='blue')
    axs.set_ylim(ylim)
    axs.set_xlim(xlim)
 #   plt.savefig(result_path + '\TrainingSession' + str(s) +'.svg')
    plt.show()
    
    #%% OTDA parameters
    rango_cl=[0.1, 1, 10]
    rango_e=[0.1, 1, 10] 
    metric = 'sqeuclidean'
    outerkfold = 20
    innerkfold = None
    M=20
    norm=None
    eps = 1e+6
    # %% Test with sessions 
    acc_lda = []
    acc_OT = []
    # now test
    for i in Test_sessions:
        print("Testing session ", i)
    
        Data_test = op.join(data_path, 'session' + str(i) +'_epochs_epo.fif')  
        epochs_test = mne.read_epochs(Data_test, preload=True, verbose=False)
        # # resample to 250 Hz
        epochs_test = epochs_test.resample(250)
        epochs_test_array = epochs_test.get_data()  # Epoched data as a numpy array
        # # Filter data 
        epochs_test_array=mne.filter.filter_data(epochs_test_array, 250, 8, 30)
        
        # i will split val and test data from here already to make the code more easy to follow
        Xte = epochs_test_array[20:].copy()  # Epoched data as a numpy array
        Yte = epochs_test.events[20:,2].copy()
        # use the first 20 samples for validation
        Xval = epochs_test_array[:20].copy()  # Epoched data as a numpy array
        Yval = epochs_test.events[:20,2].copy()

        # extract features
        Gte = csp.transform(Xte)
        Gval = csp.transform(Xval)

        y_predict_lda = lda.predict(Gte)
        acc_lda.append(accuracy_score(Yte,y_predict_lda))
        
        #  OT
        y_predict_ot = []
        Transp = []
        
        # select source subset
        G_BOTDAl1l2_, Y_BOTDAl1l2_, regu_BOTDAl1l2_=\
        SelectSubsetTraining_BOTDAl1l2(Gtr, Ytr, Gval, Yval, rango_e, rango_cl, lda, metric, outerkfold, innerkfold, M, norm)
        
        #  For each sample, make the data adaptation
        for re in range(1,len(Yte)+1):
            
            #testing trial
            Xte_ot=Xte[(re-1):(re)]
            Yte_ot=Yte[(re-1):(re)]
            
            Xval=np.vstack((Xval, Xte_ot))
            Yval=np.hstack((Yval, Yte_ot))
            
            #csp estimation
            Gval=csp.transform(Xval)
            Gte_ot=csp.transform(Xte_ot)
         
            yt_pred, transp_Xt_backward, botda_matrix = Backward_GroupLasso_Transport(G_BOTDAl1l2_, Y_BOTDAl1l2_, regu_BOTDAl1l2_, Gtr, Ytr, Gval, Yval, Gte_ot, lda, metric)
            y_predict_ot.append(yt_pred)
            #save transported data
            Transp.append(transp_Xt_backward)
          
        Gte_ot=np.squeeze(Transp)
        y_predict_ot = np.squeeze(y_predict_ot)
        
        acc_OT.append(accuracy_score(Yte,y_predict_ot))
        
        # save results
 #       dic_path = op.join(result_path, 'Sim_diffTrainings_test' + str(i) + '.npz')
 #       np.savez(dic_path, G_BOTDAl1l2_=G_BOTDAl1l2_, Y_BOTDAl1l2_ = Y_BOTDAl1l2_, regu_BOTDAl1l2_ = regu_BOTDAl1l2_, Gte_ot = Gte_ot,
 #                 botda_matrix=botda_matrix, y_tr = Yte, y_lda = y_predict_lda, y_OT = y_predict_ot )
        #Plot first 2 features
        outernMI = np.argsort(Gte[Yte==1, 0])[len(Gte[Yte==1, 0])-10:]
        outernR = np.argsort(Gte[Yte==2, 0])[0:10]
        
        x = np.linspace(-1,3,500)
        y = np.linspace(2,8,500)
        X,Y = np.meshgrid(x,y)
        pos = np.array([X.flatten(),Y.flatten()]).T
        fig, axs = plt.subplots()
        axs.scatter(features[Ytr==1, 0], features[Ytr==1, 1], c='wheat', label='MI train')
        axs.scatter(features[Ytr==2, 0], features[Ytr==2, 1], c='powderblue', label='REST train')   
        axs.scatter(Gte[Yte==1, 0], Gte[Yte==1, 1], c='orange', label='MI')   
        axs.scatter(Gte_ot[Yte==1, 0], Gte_ot[Yte==1, 1], c='chocolate', label='MI OT')    
        axs.scatter(Gte[Yte==2, 0], Gte[Yte==2, 1], c='darkturquoise', label='REST') 
        axs.scatter(Gte_ot[Yte==2, 0], Gte_ot[Yte==2, 1], c='teal', label='REST OT')
        # i will plot the subset where the transport is learned
        axs.scatter(Gval[Yval==1, 0], Gval[Yval==1, 1], c='brown', label='MI val')
        axs.scatter(Gval[Yval==2, 0], Gval[Yval==2, 1], c='blue', label='MI Gval')
        axs.scatter(G_BOTDAl1l2_[Y_BOTDAl1l2_==1, 0], G_BOTDAl1l2_[Y_BOTDAl1l2_==1, 1], c='burlywood', label='MI G_BOTDA')
        axs.scatter(G_BOTDAl1l2_[Y_BOTDAl1l2_==2, 0], G_BOTDAl1l2_[Y_BOTDAl1l2_==2, 1], c='lightslategray', label='MI G_BOTDA')
        axs.set_title('Accuracy LDA: ' + str(accuracy_score(Yte,y_predict_lda))[0:5] + 
                      '\nAccuracy OT: ' + str(accuracy_score(Yte,y_predict_ot))[0:5] + '\nsession ' + str(i) + ' ERD=' + str(erd[i-1])
                      )               
        axs.legend(loc='center left', bbox_to_anchor=(1, 0.5))        
        b, w1, w2 = lda.intercept_[0], lda.coef_[0][0], lda.coef_[0][1]
        xx = np.array(axs.get_xlim())
        ylim = np.array(axs.get_ylim())
        axs.plot(xx, -(b+xx*w1)/w2, c='blue')
        axs.set_ylim(ylim)
        axs.set_xlim(xlim)
        plt.plot([Gte[Yte==1, 0][outernMI],Gte_ot[Yte==1, 0][outernMI]], [Gte[Yte==1, 1][outernMI], Gte_ot[Yte==1, 1][outernMI]],'k-', alpha = 0.3)  
        plt.plot([Gte[Yte==2, 0][outernR],Gte_ot[Yte==2, 0][outernR]], [Gte[Yte==2, 1][outernR], Gte_ot[Yte==2, 1][outernR]],'k-', alpha = 0.3)
#        fig.savefig(op.join(result_path, 'train'+ str(Train_session) + '_test' + str(i) +'.svg'), format='svg',
#                transparent=True, dpi=2000, bbox_inches='tight', pad_inches=0)
        plt.show()

# %% compute accuracy
    acc_lda = [round(item, 2) for item in acc_lda]
    acc_OT = [round(item, 2) for item in acc_OT]
 
    Test_sessions = np.array(Test_sessions)
    info = {'Session': Test_sessions,
          'ERD' : np.squeeze(erd[[Test_sessions-1]]),
          'Acc': acc_lda, 
          'Acc with OT': acc_OT}
    table = tabulate(info, headers='keys')
    print(table)
#    with open(str(result_path +  '\Results_train_' + str(Train_session) + '.txt'), 'w') as f:
#      f.write(table)
   
##
    fig, axs = plt.subplots()
    x = np.arange(len(Test_sessions))
    bar1 = plt.bar(x-0.2, acc_lda, 0.4, color='orange', label='without OT')
    bar2 = plt.bar(x+0.2, acc_OT, 0.4, color='chocolate', label='with OT')
    plt.title('Classification Accuracy')
    plt.xlabel("ERD")
    plt.ylabel("Accuracy")
    plt.ylim([0,1])
    plt.xticks(x, np.squeeze(erd[[Test_sessions-1]]))
    plt.legend(loc='lower right')
 
    def autolabel(rects):
      """Attach a text label above each bar in *rects*, displaying its height."""
      for rect in rects:
            height = rect.get_height()
            plt.annotate('{}'.format(height),
                      xy=(rect.get_x() + rect.get_width() / 2, height),
                      xytext=(0, 3),  # 3 points vertical offset
                      textcoords="offset points",
                      ha='center', va='bottom')
    autolabel(bar1)
    autolabel(bar2)
    fig.tight_layout()
 
    #plt.savefig(result_path +  '\ACCURACY_train_' +str(Train_session) + '.svg')
    plt.show()
    
    # Fit a curve using polynomial regression
    degree = 2
    coefficients_lda = np.polyfit(x, acc_lda, degree)
    poly_lda = np.poly1d(coefficients_lda)
    fit_lda = poly_lda(x)

    coefficients_OT = np.polyfit(x, acc_OT, degree)
    poly_OT = np.poly1d(coefficients_OT)
    fit_OT = poly_OT(x)

    # Plot the original data and the fitted curves
    plt.plot(x, acc_lda, 'o', color='orange', label='LDA')
    plt.plot(x, fit_lda, color='black', label='Fitted Curve (LDA)')
    plt.plot(x, acc_OT, 'o', color='chocolate', label='OT')
    plt.plot(x, fit_OT, color='black', label='Fitted Curve (OT)')
    plt.ylim(bottom = 0)
    plt.xlabel('Sessions')
    plt.ylabel('Accuracy')
    plt.title('Accuracy')
    plt.legend()
 #   plt.savefig(result_path +  '\Fit_accuracy_train_' +str(Train_session) + '.svg')
    plt.show()
# Out:
# Computing rank from data with rank=None
#     Using tolerance 6.5e-05 (2.2e-16 eps * 41 dim * 7.2e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.6e-05 (2.2e-16 eps * 41 dim * 5.1e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.3e-05 (2.2e-16 eps * 41 dim * 5.8e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.7e-05 (2.2e-16 eps * 41 dim * 8.5e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.7e-05 (2.2e-16 eps * 41 dim * 8.4e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.0001 (2.2e-16 eps * 41 dim * 1.2e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.8e-05 (2.2e-16 eps * 41 dim * 7.5e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.1e-05 (2.2e-16 eps * 41 dim * 6.7e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.4e-05 (2.2e-16 eps * 41 dim * 8.2e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.6e-05 (2.2e-16 eps * 41 dim * 8.3e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.2e-05 (2.2e-16 eps * 41 dim * 9e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.5e-05 (2.2e-16 eps * 41 dim * 9.3e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.7e-05 (2.2e-16 eps * 41 dim * 9.5e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.7e-05 (2.2e-16 eps * 41 dim * 7.4e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.7e-05 (2.2e-16 eps * 41 dim * 1.1e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.2e-05 (2.2e-16 eps * 41 dim * 9e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.1e-05 (2.2e-16 eps * 41 dim * 5.6e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.1e-05 (2.2e-16 eps * 41 dim * 6.7e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.5e-05 (2.2e-16 eps * 41 dim * 7.1e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.4e-05 (2.2e-16 eps * 41 dim * 8.1e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.2e-05 (2.2e-16 eps * 41 dim * 7.9e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.4e-05 (2.2e-16 eps * 41 dim * 9.3e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.1e-05 (2.2e-16 eps * 41 dim * 8.9e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.1e-05 (2.2e-16 eps * 41 dim * 1e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-05 (2.2e-16 eps * 41 dim * 1e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00011 (2.2e-16 eps * 41 dim * 1.2e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.3e-05 (2.2e-16 eps * 41 dim * 6.9e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.4e-05 (2.2e-16 eps * 41 dim * 8.2e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.6e-05 (2.2e-16 eps * 41 dim * 8.4e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.7e-05 (2.2e-16 eps * 41 dim * 1.1e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.2e-05 (2.2e-16 eps * 41 dim * 6.8e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00013 (2.2e-16 eps * 41 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.8e-05 (2.2e-16 eps * 41 dim * 6.4e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.9e-05 (2.2e-16 eps * 41 dim * 7.6e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6e-05 (2.2e-16 eps * 41 dim * 6.6e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5e-05 (2.2e-16 eps * 41 dim * 5.5e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.7e-05 (2.2e-16 eps * 41 dim * 7.4e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.2e-05 (2.2e-16 eps * 41 dim * 9e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.2e-05 (2.2e-16 eps * 41 dim * 5.7e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.7e-05 (2.2e-16 eps * 41 dim * 6.2e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.6e-05 (2.2e-16 eps * 41 dim * 7.2e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00014 (2.2e-16 eps * 41 dim * 1.5e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00016 (2.2e-16 eps * 41 dim * 1.7e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00013 (2.2e-16 eps * 41 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.1e-05 (2.2e-16 eps * 41 dim * 8.9e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.3e-05 (2.2e-16 eps * 41 dim * 6.9e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.6e-05 (2.2e-16 eps * 41 dim * 9.5e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.2e-05 (2.2e-16 eps * 41 dim * 7.9e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6e-05 (2.2e-16 eps * 41 dim * 6.6e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.6e-05 (2.2e-16 eps * 41 dim * 6.1e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.7e-05 (2.2e-16 eps * 41 dim * 6.2e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9e-05 (2.2e-16 eps * 41 dim * 9.9e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.6e-05 (2.2e-16 eps * 41 dim * 8.3e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.9e-05 (2.2e-16 eps * 41 dim * 8.7e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00011 (2.2e-16 eps * 41 dim * 1.2e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.8e-05 (2.2e-16 eps * 41 dim * 8.6e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.1e-05 (2.2e-16 eps * 41 dim * 7.7e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.6e-05 (2.2e-16 eps * 41 dim * 7.3e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.8e-05 (2.2e-16 eps * 41 dim * 1.1e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00017 (2.2e-16 eps * 41 dim * 1.9e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.4e-05 (2.2e-16 eps * 41 dim * 7e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.9e-05 (2.2e-16 eps * 41 dim * 8.7e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00012 (2.2e-16 eps * 41 dim * 1.3e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.1e-05 (2.2e-16 eps * 41 dim * 7.8e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.6e-05 (2.2e-16 eps * 41 dim * 8.4e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.1e-05 (2.2e-16 eps * 41 dim * 5.6e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.2e-05 (2.2e-16 eps * 41 dim * 6.8e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.7e-05 (2.2e-16 eps * 41 dim * 1.1e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.6e-05 (2.2e-16 eps * 41 dim * 1e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.2e-05 (2.2e-16 eps * 41 dim * 5.7e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.8e-05 (2.2e-16 eps * 41 dim * 1.1e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.0001 (2.2e-16 eps * 41 dim * 1.1e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00011 (2.2e-16 eps * 41 dim * 1.2e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00011 (2.2e-16 eps * 41 dim * 1.3e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00015 (2.2e-16 eps * 41 dim * 1.6e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00014 (2.2e-16 eps * 41 dim * 1.5e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00016 (2.2e-16 eps * 41 dim * 1.8e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.2e-05 (2.2e-16 eps * 41 dim * 1e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00013 (2.2e-16 eps * 41 dim * 1.5e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00014 (2.2e-16 eps * 41 dim * 1.5e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00016 (2.2e-16 eps * 41 dim * 1.8e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00014 (2.2e-16 eps * 41 dim * 1.5e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00014 (2.2e-16 eps * 41 dim * 1.5e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00014 (2.2e-16 eps * 41 dim * 1.5e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00015 (2.2e-16 eps * 41 dim * 1.7e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.3e-05 (2.2e-16 eps * 41 dim * 1e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.3e-05 (2.2e-16 eps * 41 dim * 9.1e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6e-05 (2.2e-16 eps * 41 dim * 6.6e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.3e-05 (2.2e-16 eps * 41 dim * 5.8e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.6e-05 (2.2e-16 eps * 41 dim * 8.3e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.4e-05 (2.2e-16 eps * 41 dim * 7e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7e-05 (2.2e-16 eps * 41 dim * 7.7e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.8e-05 (2.2e-16 eps * 41 dim * 6.4e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.8e-05 (2.2e-16 eps * 41 dim * 7.4e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.2e-05 (2.2e-16 eps * 41 dim * 6.8e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00011 (2.2e-16 eps * 41 dim * 1.2e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.6e-05 (2.2e-16 eps * 41 dim * 7.3e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.4e-05 (2.2e-16 eps * 41 dim * 5.9e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.7e-05 (2.2e-16 eps * 41 dim * 8.4e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.6e-05 (2.2e-16 eps * 41 dim * 6.2e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5e-05 (2.2e-16 eps * 41 dim * 5.5e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.7e-05 (2.2e-16 eps * 41 dim * 7.3e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.6e-05 (2.2e-16 eps * 41 dim * 7.3e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.6e-05 (2.2e-16 eps * 41 dim * 6.1e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.7e-05 (2.2e-16 eps * 41 dim * 6.2e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.2e-05 (2.2e-16 eps * 41 dim * 1e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.1e-05 (2.2e-16 eps * 41 dim * 8.9e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.8e-05 (2.2e-16 eps * 41 dim * 7.4e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7e-05 (2.2e-16 eps * 41 dim * 7.7e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.2e-05 (2.2e-16 eps * 41 dim * 5.7e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.4e-05 (2.2e-16 eps * 41 dim * 8.1e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.4e-05 (2.2e-16 eps * 41 dim * 9.2e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00011 (2.2e-16 eps * 41 dim * 1.3e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.8e-05 (2.2e-16 eps * 41 dim * 6.3e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.8e-05 (2.2e-16 eps * 41 dim * 1.1e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.8e-05 (2.2e-16 eps * 41 dim * 8.6e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.4e-05 (2.2e-16 eps * 41 dim * 9.2e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.5e-05 (2.2e-16 eps * 41 dim * 8.2e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00012 (2.2e-16 eps * 41 dim * 1.3e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.2e-05 (2.2e-16 eps * 41 dim * 7.9e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.8e-05 (2.2e-16 eps * 41 dim * 6.3e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.2e-05 (2.2e-16 eps * 41 dim * 5.8e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.0001 (2.2e-16 eps * 41 dim * 1.1e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6e-05 (2.2e-16 eps * 41 dim * 6.6e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.9e-05 (2.2e-16 eps * 41 dim * 8.6e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.7e-05 (2.2e-16 eps * 41 dim * 6.3e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.1e-05 (2.2e-16 eps * 41 dim * 6.7e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.7e-05 (2.2e-16 eps * 41 dim * 7.3e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.2e-05 (2.2e-16 eps * 41 dim * 9e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.6e-05 (2.2e-16 eps * 41 dim * 8.3e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.7e-05 (2.2e-16 eps * 41 dim * 8.5e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.8e-05 (2.2e-16 eps * 41 dim * 8.6e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.6e-05 (2.2e-16 eps * 41 dim * 7.2e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.7e-05 (2.2e-16 eps * 41 dim * 1.1e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-05 (2.2e-16 eps * 41 dim * 1e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.1e-05 (2.2e-16 eps * 41 dim * 7.8e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.8e-05 (2.2e-16 eps * 41 dim * 8.6e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.9e-05 (2.2e-16 eps * 41 dim * 5.3e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.2e-05 (2.2e-16 eps * 41 dim * 6.8e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7e-05 (2.2e-16 eps * 41 dim * 7.7e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7e-05 (2.2e-16 eps * 41 dim * 7.7e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.2e-05 (2.2e-16 eps * 41 dim * 7.9e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.9e-05 (2.2e-16 eps * 41 dim * 7.6e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00012 (2.2e-16 eps * 41 dim * 1.3e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.5e-05 (2.2e-16 eps * 41 dim * 8.2e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.7e-05 (2.2e-16 eps * 41 dim * 6.3e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.5e-05 (2.2e-16 eps * 41 dim * 6.1e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.3e-05 (2.2e-16 eps * 41 dim * 8e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.6e-05 (2.2e-16 eps * 41 dim * 5e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.1e-05 (2.2e-16 eps * 41 dim * 5.6e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.0001 (2.2e-16 eps * 41 dim * 1.1e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.9e-05 (2.2e-16 eps * 41 dim * 8.7e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5e-05 (2.2e-16 eps * 41 dim * 5.5e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.6e-05 (2.2e-16 eps * 41 dim * 9.4e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00012 (2.2e-16 eps * 41 dim * 1.3e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00013 (2.2e-16 eps * 41 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00012 (2.2e-16 eps * 41 dim * 1.3e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00019 (2.2e-16 eps * 41 dim * 2.1e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.4e-05 (2.2e-16 eps * 41 dim * 8.1e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.1e-05 (2.2e-16 eps * 41 dim * 6.7e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.9e-05 (2.2e-16 eps * 41 dim * 7.5e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6e-05 (2.2e-16 eps * 41 dim * 6.5e+09  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00011 (2.2e-16 eps * 41 dim * 1.2e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00012 (2.2e-16 eps * 41 dim * 1.3e+10  max singular value)
#     Estimated rank (mag): 41
#     MAG: rank 41 computed from 41 data channels with 0 projectors
# Reducing data rank from 41 -> 41
# Estimating covariance using EMPIRICAL
# Done.
# ...
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# /usr/local/lib/python3.10/dist-packages/ot/bregman.py:535: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# <ipython-input-11-d32acbd987d8>:168: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   'ERD' : np.squeeze(erd[[Test_sessions-1]]),
# <ipython-input-11-d32acbd987d8>:185: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   plt.xticks(x, np.squeeze(erd[[Test_sessions-1]]))
#   Session    ERD    Acc    Acc with OT
# ---------  -----  -----  -------------
#         1   0.5    0.48           0.52
#         2   0.45   0.54           0.5
#         3   0.4    0.48           0.49
#         4   0.35   0.5            0.54
#         5   0.3    0.42           0.46
#         6   0.25   0.47           0.51
#         7   0.2    0.49           0.51
#         8   0.15   0.46           0.39
